# %% [markdown]
# A Convolutional Network implementation example using TensorFlow library.
# This example is using the MNIST database of handwritten digits
# (http://yann.lecun.com/exdb/mnist/)
#
# Author: Aymeric Damien
# Project: https://github.com/aymericdamien/TensorFlow-Examples/

# %%
import tensorflow as tf

# %%
if tf.test.is_gpu_available():
    print("GPU available.\nSpecs: \n")
    # !nvidia-smi
else:
    print("No GPU found... Defaulting to CPU.")
# Out:
# GPU available.
# Specs:
#
# Sun Aug 26 15:33:35 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 390.48                 Driver Version: 390.48                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:1E.0 Off |                    0 |
# | N/A   36C    P0    79W / 149W |  10880MiB / 11441MiB |      9%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/floyd/input/mnist", one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-3-753b9f5d8697>:3: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /floyd/input/mnist/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /floyd/input/mnist/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting /floyd/input/mnist/t10k-images-idx3-ubyte.gz
# Extracting /floyd/input/mnist/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input], name="x")
y = tf.placeholder(tf.float32, [None, n_classes], name="y")
keep_prob = tf.placeholder(tf.float32, name="keep_prob") #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name="accuracy")

# Initializing the variables
init = tf.global_variables_initializer()
builder = tf.saved_model.builder.SavedModelBuilder("./model")
# TODO: This step throws an error "folder already exists". How do I solve this?
# Out:
# WARNING:tensorflow:From <ipython-input-6-e79197f82042>:24: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            # print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
            print('{{"metric": "Minibatch loss", "value": {:.6f}}}'.format(loss))
            print('{{"metric": "Training accuracy", "value": {:.5f}}}'.format(acc))
        step += 1
    print("Optimization Finished!")

    builder.add_meta_graph_and_variables(sess, ["EVALUATING"])

builder.save()
# Out:
# Iter 1280, Minibatch Loss= 26055.583984, Training Accuracy= 0.23438
# Iter 2560, Minibatch Loss= 10214.936523, Training Accuracy= 0.49219
# Iter 3840, Minibatch Loss= 7568.085938, Training Accuracy= 0.68750
# Iter 5120, Minibatch Loss= 3739.742676, Training Accuracy= 0.73438
# Iter 6400, Minibatch Loss= 3635.356934, Training Accuracy= 0.82812
# Iter 7680, Minibatch Loss= 3828.306396, Training Accuracy= 0.80469
# Iter 8960, Minibatch Loss= 3115.182617, Training Accuracy= 0.78906
# Iter 10240, Minibatch Loss= 2833.702881, Training Accuracy= 0.86719
# Iter 11520, Minibatch Loss= 3542.973389, Training Accuracy= 0.82812
# Iter 12800, Minibatch Loss= 2674.258301, Training Accuracy= 0.79688
# Iter 14080, Minibatch Loss= 1006.690613, Training Accuracy= 0.93750
# Iter 15360, Minibatch Loss= 1629.419189, Training Accuracy= 0.86719
# Iter 16640, Minibatch Loss= 540.980957, Training Accuracy= 0.94531
# Iter 17920, Minibatch Loss= 1958.431274, Training Accuracy= 0.89062
# Iter 19200, Minibatch Loss= 1585.746582, Training Accuracy= 0.90625
# Iter 20480, Minibatch Loss= 881.413330, Training Accuracy= 0.90625
# Iter 21760, Minibatch Loss= 2471.883057, Training Accuracy= 0.89062
# Iter 23040, Minibatch Loss= 1906.132812, Training Accuracy= 0.85938
# Iter 24320, Minibatch Loss= 1932.195923, Training Accuracy= 0.90625
# Iter 25600, Minibatch Loss= 1543.774780, Training Accuracy= 0.89844
# Iter 26880, Minibatch Loss= 1216.528442, Training Accuracy= 0.95312
# Iter 28160, Minibatch Loss= 319.560303, Training Accuracy= 0.94531
# Iter 29440, Minibatch Loss= 919.963135, Training Accuracy= 0.92188
# Iter 30720, Minibatch Loss= 892.995972, Training Accuracy= 0.96875
# Iter 32000, Minibatch Loss= 456.447754, Training Accuracy= 0.96875
# Iter 33280, Minibatch Loss= 1592.211426, Training Accuracy= 0.89062
# Iter 34560, Minibatch Loss= 2180.342529, Training Accuracy= 0.91406
# Iter 35840, Minibatch Loss= 989.980225, Training Accuracy= 0.91406
# Iter 37120, Minibatch Loss= 1193.352783, Training Accuracy= 0.89062
# Iter 38400, Minibatch Loss= 426.372528, Training Accuracy= 0.95312
# Iter 39680, Minibatch Loss= 1127.277222, Training Accuracy= 0.91406
# Iter 40960, Minibatch Loss= 623.972290, Training Accuracy= 0.92969
# Iter 42240, Minibatch Loss= 1293.777100, Training Accuracy= 0.92969
# Iter 43520, Minibatch Loss= 1162.414917, Training Accuracy= 0.92969
# Iter 44800, Minibatch Loss= 976.971436, Training Accuracy= 0.92188
# Iter 46080, Minibatch Loss= 939.292786, Training Accuracy= 0.92188
# Iter 47360, Minibatch Loss= 680.395813, Training Accuracy= 0.96094
# Iter 48640, Minibatch Loss= 434.039307, Training Accuracy= 0.96094
# Iter 49920, Minibatch Loss= 538.365051, Training Accuracy= 0.92969
# Iter 51200, Minibatch Loss= 1.151428, Training Accuracy= 0.99219
# Iter 52480, Minibatch Loss= 803.944824, Training Accuracy= 0.92969
# Iter 53760, Minibatch Loss= 770.934937, Training Accuracy= 0.96875
# Iter 55040, Minibatch Loss= 693.447998, Training Accuracy= 0.95312
# Iter 56320, Minibatch Loss= 646.105835, Training Accuracy= 0.94531
# Iter 57600, Minibatch Loss= 524.829590, Training Accuracy= 0.96094
# Iter 58880, Minibatch Loss= 587.096069, Training Accuracy= 0.95312
# Iter 60160, Minibatch Loss= 684.615967, Training Accuracy= 0.96875
# Iter 61440, Minibatch Loss= 481.231262, Training Accuracy= 0.94531
# Iter 62720, Minibatch Loss= 379.730530, Training Accuracy= 0.95312
# Iter 64000, Minibatch Loss= 299.091217, Training Accuracy= 0.94531
# Iter 65280, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 66560, Minibatch Loss= 693.885193, Training Accuracy= 0.94531
# Iter 67840, Minibatch Loss= 535.245117, Training Accuracy= 0.95312
# Iter 69120, Minibatch Loss= 638.568787, Training Accuracy= 0.95312
# Iter 70400, Minibatch Loss= 524.782898, Training Accuracy= 0.96875
# Iter 71680, Minibatch Loss= 262.707794, Training Accuracy= 0.97656
# Iter 72960, Minibatch Loss= 98.488266, Training Accuracy= 0.97656
# Iter 74240, Minibatch Loss= 268.274231, Training Accuracy= 0.97656
# Iter 75520, Minibatch Loss= 585.230591, Training Accuracy= 0.95312
# Iter 76800, Minibatch Loss= 66.049561, Training Accuracy= 0.99219
# Iter 78080, Minibatch Loss= 131.475998, Training Accuracy= 0.97656
# Iter 79360, Minibatch Loss= 134.135239, Training Accuracy= 0.96875
# Iter 80640, Minibatch Loss= 607.872070, Training Accuracy= 0.94531
# Iter 81920, Minibatch Loss= 169.914978, Training Accuracy= 0.97656
# Iter 83200, Minibatch Loss= 198.515228, Training Accuracy= 0.96875
# Iter 84480, Minibatch Loss= 359.140594, Training Accuracy= 0.97656
# Iter 85760, Minibatch Loss= 351.463470, Training Accuracy= 0.96094
# Iter 87040, Minibatch Loss= 342.728577, Training Accuracy= 0.95312
# Iter 88320, Minibatch Loss= 329.705139, Training Accuracy= 0.96875
# Iter 89600, Minibatch Loss= 529.355591, Training Accuracy= 0.95312
# Iter 90880, Minibatch Loss= 104.167290, Training Accuracy= 0.98438
# Iter 92160, Minibatch Loss= 1126.834717, Training Accuracy= 0.91406
# Iter 93440, Minibatch Loss= 743.587280, Training Accuracy= 0.95312
# Iter 94720, Minibatch Loss= 336.793396, Training Accuracy= 0.95312
# Iter 96000, Minibatch Loss= 326.611145, Training Accuracy= 0.96875
# Iter 97280, Minibatch Loss= 252.305389, Training Accuracy= 0.96875
# Iter 98560, Minibatch Loss= 249.974762, Training Accuracy= 0.95312
# Iter 99840, Minibatch Loss= 311.767303, Training Accuracy= 0.96875
# Iter 101120, Minibatch Loss= 761.846313, Training Accuracy= 0.91406
# Iter 102400, Minibatch Loss= 714.739319, Training Accuracy= 0.95312
# Iter 103680, Minibatch Loss= 150.738556, Training Accuracy= 0.98438
# Iter 104960, Minibatch Loss= 114.959290, Training Accuracy= 0.96875
# Iter 106240, Minibatch Loss= 131.178741, Training Accuracy= 0.96875
# Iter 107520, Minibatch Loss= 447.325806, Training Accuracy= 0.96094
# Iter 108800, Minibatch Loss= 389.749115, Training Accuracy= 0.96094
# Iter 110080, Minibatch Loss= 335.718445, Training Accuracy= 0.97656
# Iter 111360, Minibatch Loss= 63.907997, Training Accuracy= 0.98438
# Iter 112640, Minibatch Loss= 179.809601, Training Accuracy= 0.95312
# Iter 113920, Minibatch Loss= 164.902924, Training Accuracy= 0.96094
# Iter 115200, Minibatch Loss= 496.132721, Training Accuracy= 0.93750
# Iter 116480, Minibatch Loss= 333.671448, Training Accuracy= 0.96094
# Iter 117760, Minibatch Loss= 77.240784, Training Accuracy= 0.99219
# Iter 119040, Minibatch Loss= 439.648163, Training Accuracy= 0.96875
# Iter 120320, Minibatch Loss= 131.315125, Training Accuracy= 0.98438
# Iter 121600, Minibatch Loss= 141.302933, Training Accuracy= 0.96875
# Iter 122880, Minibatch Loss= 103.749832, Training Accuracy= 0.97656
# Iter 124160, Minibatch Loss= 243.251694, Training Accuracy= 0.98438
# Iter 125440, Minibatch Loss= 19.545807, Training Accuracy= 0.98438
# Iter 126720, Minibatch Loss= 116.227577, Training Accuracy= 0.96875
# Iter 128000, Minibatch Loss= 495.438843, Training Accuracy= 0.96094
# Iter 129280, Minibatch Loss= 286.130493, Training Accuracy= 0.96875
# Iter 130560, Minibatch Loss= 70.444557, Training Accuracy= 0.98438
# Iter 131840, Minibatch Loss= 329.952820, Training Accuracy= 0.96094
# Iter 133120, Minibatch Loss= 479.519958, Training Accuracy= 0.97656
# Iter 134400, Minibatch Loss= 16.316856, Training Accuracy= 0.98438
# Iter 135680, Minibatch Loss= 108.153046, Training Accuracy= 0.96875
# Iter 136960, Minibatch Loss= 174.984283, Training Accuracy= 0.97656
# Iter 138240, Minibatch Loss= 304.216583, Training Accuracy= 0.96094
# Iter 139520, Minibatch Loss= 691.522644, Training Accuracy= 0.95312
# Iter 140800, Minibatch Loss= 157.616379, Training Accuracy= 0.97656
# Iter 142080, Minibatch Loss= 146.363922, Training Accuracy= 0.98438
# Iter 143360, Minibatch Loss= 123.306595, Training Accuracy= 0.97656
# Iter 144640, Minibatch Loss= 293.382568, Training Accuracy= 0.96875
# Iter 145920, Minibatch Loss= 55.357750, Training Accuracy= 0.98438
# Iter 147200, Minibatch Loss= 37.314621, Training Accuracy= 0.99219
# Iter 148480, Minibatch Loss= 293.517365, Training Accuracy= 0.96875
# Iter 149760, Minibatch Loss= 0.749161, Training Accuracy= 0.99219
# Iter 151040, Minibatch Loss= 213.876160, Training Accuracy= 0.98438
# Iter 152320, Minibatch Loss= 216.579697, Training Accuracy= 0.96875
# Iter 153600, Minibatch Loss= 282.585144, Training Accuracy= 0.96094
# Iter 154880, Minibatch Loss= 99.717140, Training Accuracy= 0.97656
# Iter 156160, Minibatch Loss= 24.170731, Training Accuracy= 0.97656
# Iter 157440, Minibatch Loss= 405.227142, Training Accuracy= 0.97656
# Iter 158720, Minibatch Loss= 441.559265, Training Accuracy= 0.96094
# Iter 160000, Minibatch Loss= 294.891113, Training Accuracy= 0.97656
# Iter 161280, Minibatch Loss= 138.938492, Training Accuracy= 0.97656
# Iter 162560, Minibatch Loss= 133.372330, Training Accuracy= 0.96875
# Iter 163840, Minibatch Loss= 1.770370, Training Accuracy= 0.99219
# Iter 165120, Minibatch Loss= 209.692642, Training Accuracy= 0.96875
# Iter 166400, Minibatch Loss= 91.448151, Training Accuracy= 0.97656
# Iter 167680, Minibatch Loss= 87.957695, Training Accuracy= 0.96875
# Iter 168960, Minibatch Loss= 327.589722, Training Accuracy= 0.96875
# Iter 170240, Minibatch Loss= 135.543991, Training Accuracy= 0.97656
# Iter 171520, Minibatch Loss= 233.610962, Training Accuracy= 0.96875
# Iter 172800, Minibatch Loss= 86.604073, Training Accuracy= 0.96875
# Iter 174080, Minibatch Loss= 432.201202, Training Accuracy= 0.94531
# Iter 175360, Minibatch Loss= 190.140778, Training Accuracy= 0.97656
# Iter 176640, Minibatch Loss= 73.635422, Training Accuracy= 0.98438
# Iter 177920, Minibatch Loss= 30.193726, Training Accuracy= 0.99219
# Iter 179200, Minibatch Loss= 142.116364, Training Accuracy= 0.98438
# Iter 180480, Minibatch Loss= 26.491188, Training Accuracy= 0.99219
# Iter 181760, Minibatch Loss= 253.420288, Training Accuracy= 0.97656
# Iter 183040, Minibatch Loss= 252.310059, Training Accuracy= 0.96094
# Iter 184320, Minibatch Loss= 3.109711, Training Accuracy= 0.99219
# Iter 185600, Minibatch Loss= 172.374695, Training Accuracy= 0.98438
# Iter 186880, Minibatch Loss= 262.054810, Training Accuracy= 0.96094
# Iter 188160, Minibatch Loss= 252.703140, Training Accuracy= 0.99219
# Iter 189440, Minibatch Loss= 105.001373, Training Accuracy= 0.97656
# Iter 190720, Minibatch Loss= 182.967712, Training Accuracy= 0.96094
# Iter 192000, Minibatch Loss= 43.280060, Training Accuracy= 0.96875
# Iter 193280, Minibatch Loss= 95.671783, Training Accuracy= 0.98438
# Iter 194560, Minibatch Loss= 190.078094, Training Accuracy= 0.96094
# Iter 195840, Minibatch Loss= 147.673935, Training Accuracy= 0.97656
# Iter 197120, Minibatch Loss= 288.831848, Training Accuracy= 0.97656
# Iter 198400, Minibatch Loss= 146.337036, Training Accuracy= 0.97656
# Iter 199680, Minibatch Loss= 126.896553, Training Accuracy= 0.97656
# Optimization Finished!
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'./model/saved_model.pb'
# b'./model/saved_model.pb'

# %%
with tf.Session() as sess:
    sess.run(init)
    
    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", sess.run(accuracy, feed_dict={x: mnist.test.images[:256], y: mnist.test.labels[:256], keep_prob: 1.}))
# Out:
# Testing Accuracy: 0.078125
