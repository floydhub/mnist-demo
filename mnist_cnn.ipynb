# %% [markdown]
# ### MNIST CNN
#
# A Convolutional Network implementation example using TensorFlow library.
# This example is using the MNIST database of handwritten digits
# (http://yann.lecun.com/exdb/mnist/)
#
# Author: Aymeric Damien
# Project: https://github.com/aymericdamien/TensorFlow-Examples/

# %%
import os
import shutil
import tensorflow as tf

# %%
if tf.test.is_gpu_available():
    print("GPU available.\nSpecs: \n")
    # !nvidia-smi
else:
    print("No GPU found... Defaulting to CPU.")
# Out:
# GPU available.
# Specs:
#
# Fri Sep  7 22:13:43 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 396.54                 Driver Version: 396.54                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:1E.0 Off |                    0 |
# | N/A   61C    P0    85W / 149W |  10876MiB / 11441MiB |      5%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# Import MNIST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/floyd/input/mnist", one_hot=True)
# Out:
# Extracting /floyd/input/mnist/train-images-idx3-ubyte.gz
# Extracting /floyd/input/mnist/train-labels-idx1-ubyte.gz
# Extracting /floyd/input/mnist/t10k-images-idx3-ubyte.gz
# Extracting /floyd/input/mnist/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.001
training_iters = 200000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

logs_path = './logs/'

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input], name="x")
y = tf.placeholder(tf.float32, [None, n_classes], name="y")
keep_prob = tf.placeholder(tf.float32, name="keep_prob") #dropout (keep probability)

# %%
# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# %%
# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name="accuracy")

# Create a summary to monitor cost tensor
tf.summary.scalar("loss", cost)
# Create a summary to monitor accuracy tensor
tf.summary.scalar("accuracy", accuracy)
# Merge all summaries into a single op
merged_summary_op = tf.summary.merge_all()

# Delete ./model dir if exists to avoid SavedModelBuilder error
if os.path.exists('./model'):
    shutil.rmtree('./model', ignore_errors=True)
    
# Initializing the variables
init = tf.global_variables_initializer()
builder = tf.saved_model.builder.SavedModelBuilder("./model")
# Out:
# WARNING:tensorflow:From <ipython-input-6-0077e4435775>:24: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    
    # op to write logs to Tensorboard
    summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())
    
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        
        # Run optimization op (backprop), cost op (to get loss value) and summary nodes
        _, c, summary = sess.run([optimizer, cost, merged_summary_op], 
                                    feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
        
        # Write logs at every iteration
        summary_writer.add_summary(summary, step * batch_size)
        
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            # print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
            #      "{:.6f}".format(loss) + ", Training Accuracy= " + \
            #      "{:.5f}".format(acc))
            print('{{"metric": "Minibatch loss", "value": {:.6f}}}'.format(loss))
            print('{{"metric": "Training accuracy", "value": {:.5f}}}'.format(acc))
        step += 1
    print("Optimization Finished!")

    builder.add_meta_graph_and_variables(sess, ["EVALUATING"])

builder.save()
# Out:
# {"metric": "Minibatch loss", "value": 14612.599609}
# {"metric": "Training accuracy", "value": 0.39062}
# {"metric": "Minibatch loss", "value": 9827.154297}
# {"metric": "Training accuracy", "value": 0.60938}
# {"metric": "Minibatch loss", "value": 3431.417969}
# {"metric": "Training accuracy", "value": 0.75781}
# {"metric": "Minibatch loss", "value": 5153.578613}
# {"metric": "Training accuracy", "value": 0.75781}
# {"metric": "Minibatch loss", "value": 2701.952393}
# {"metric": "Training accuracy", "value": 0.85156}
# {"metric": "Minibatch loss", "value": 4444.277344}
# {"metric": "Training accuracy", "value": 0.75781}
# {"metric": "Minibatch loss", "value": 2107.426758}
# {"metric": "Training accuracy", "value": 0.85156}
# {"metric": "Minibatch loss", "value": 2121.080811}
# {"metric": "Training accuracy", "value": 0.84375}
# {"metric": "Minibatch loss", "value": 1686.530273}
# {"metric": "Training accuracy", "value": 0.87500}
# {"metric": "Minibatch loss", "value": 2615.851562}
# {"metric": "Training accuracy", "value": 0.86719}
# {"metric": "Minibatch loss", "value": 2157.554688}
# {"metric": "Training accuracy", "value": 0.89062}
# {"metric": "Minibatch loss", "value": 2353.160156}
# {"metric": "Training accuracy", "value": 0.87500}
# {"metric": "Minibatch loss", "value": 1957.043091}
# {"metric": "Training accuracy", "value": 0.92188}
# {"metric": "Minibatch loss", "value": 1128.000732}
# {"metric": "Training accuracy", "value": 0.90625}
# {"metric": "Minibatch loss", "value": 1702.037354}
# {"metric": "Training accuracy", "value": 0.90625}
# {"metric": "Minibatch loss", "value": 1243.490845}
# {"metric": "Training accuracy", "value": 0.87500}
# {"metric": "Minibatch loss", "value": 533.521240}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 1668.980713}
# {"metric": "Training accuracy", "value": 0.87500}
# {"metric": "Minibatch loss", "value": 1143.786255}
# {"metric": "Training accuracy", "value": 0.92188}
# {"metric": "Minibatch loss", "value": 470.046692}
# {"metric": "Training accuracy", "value": 0.92969}
# {"metric": "Minibatch loss", "value": 829.994873}
# {"metric": "Training accuracy", "value": 0.92969}
# {"metric": "Minibatch loss", "value": 1141.459717}
# {"metric": "Training accuracy", "value": 0.91406}
# {"metric": "Minibatch loss", "value": 1353.867554}
# {"metric": "Training accuracy", "value": 0.91406}
# {"metric": "Minibatch loss", "value": 343.723602}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 591.427979}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 754.989990}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 468.836426}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 859.823059}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 1214.445435}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 1561.179688}
# {"metric": "Training accuracy", "value": 0.90625}
# {"metric": "Minibatch loss", "value": 695.835571}
# {"metric": "Training accuracy", "value": 0.92969}
# {"metric": "Minibatch loss", "value": 326.790039}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 575.396790}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 1183.162109}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 367.617310}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 733.932739}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 897.733887}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 510.103485}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 1474.493896}
# {"metric": "Training accuracy", "value": 0.92188}
# {"metric": "Minibatch loss", "value": 724.748901}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 368.277252}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 464.268616}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 381.701294}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 369.268433}
# {"metric": "Training accuracy", "value": 0.92969}
# {"metric": "Minibatch loss", "value": 861.415161}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 545.133179}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 560.594604}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 1016.210510}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 160.677246}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 58.048431}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 233.581833}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 589.006531}
# {"metric": "Training accuracy", "value": 0.92188}
# {"metric": "Minibatch loss", "value": 589.754395}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 634.583923}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 77.011154}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 313.237579}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 790.818726}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 239.733597}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 512.488281}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 277.907043}
# {"metric": "Training accuracy", "value": 0.92969}
# {"metric": "Minibatch loss", "value": 528.972351}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 47.223167}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 857.834839}
# {"metric": "Training accuracy", "value": 0.92969}
# {"metric": "Minibatch loss", "value": 414.263763}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 210.532333}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 486.151184}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 119.391052}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 389.152985}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 574.559204}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 295.246643}
# {"metric": "Training accuracy", "value": 0.96094}
# {"metric": "Minibatch loss", "value": 235.132141}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 617.503113}
# {"metric": "Training accuracy", "value": 0.92188}
# {"metric": "Minibatch loss", "value": 34.002609}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 354.495392}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 294.217285}
# {"metric": "Training accuracy", "value": 0.96094}
# {"metric": "Minibatch loss", "value": 350.603577}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 451.157990}
# {"metric": "Training accuracy", "value": 0.92969}
# {"metric": "Minibatch loss", "value": 245.821075}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 854.932983}
# {"metric": "Training accuracy", "value": 0.92969}
# {"metric": "Minibatch loss", "value": 291.048309}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 128.316635}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 318.904663}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 73.215683}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 549.928711}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 397.128235}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 67.854401}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 58.947678}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 237.991959}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 418.569153}
# {"metric": "Training accuracy", "value": 0.93750}
# {"metric": "Minibatch loss", "value": 390.227264}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 342.484802}
# {"metric": "Training accuracy", "value": 0.96094}
# {"metric": "Minibatch loss", "value": 308.402100}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 402.612976}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 113.961357}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 227.303543}
# {"metric": "Training accuracy", "value": 0.96094}
# {"metric": "Minibatch loss", "value": 142.668823}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 163.173233}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 222.267212}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 167.343567}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 52.208576}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 296.749847}
# {"metric": "Training accuracy", "value": 0.96094}
# {"metric": "Minibatch loss", "value": 262.259155}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 239.454758}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 472.043671}
# {"metric": "Training accuracy", "value": 0.96094}
# {"metric": "Minibatch loss", "value": 24.822357}
# {"metric": "Training accuracy", "value": 0.99219}
# {"metric": "Minibatch loss", "value": 248.111115}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 370.727600}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 67.517258}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 114.689056}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 129.667618}
# {"metric": "Training accuracy", "value": 0.96094}
# {"metric": "Minibatch loss", "value": 364.676147}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 174.290710}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 342.932739}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 13.420685}
# {"metric": "Training accuracy", "value": 0.99219}
# {"metric": "Minibatch loss", "value": 124.369690}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 20.484772}
# {"metric": "Training accuracy", "value": 0.99219}
# {"metric": "Minibatch loss", "value": 500.841553}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 351.654419}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 125.683792}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 263.697906}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 12.862526}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 229.709000}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 285.007263}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 178.308243}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 11.162933}
# {"metric": "Training accuracy", "value": 0.99219}
# {"metric": "Minibatch loss", "value": 343.702362}
# {"metric": "Training accuracy", "value": 0.94531}
# {"metric": "Minibatch loss", "value": 94.929268}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 142.603760}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 246.369812}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 55.173767}
# {"metric": "Training accuracy", "value": 0.99219}
# {"metric": "Minibatch loss", "value": 0.000000}
# {"metric": "Training accuracy", "value": 1.00000}
# {"metric": "Minibatch loss", "value": 69.841583}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 43.601883}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 10.909302}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 330.245056}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 82.224190}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 231.812256}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 121.648491}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 113.121933}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 87.285255}
# {"metric": "Training accuracy", "value": 0.96094}
# {"metric": "Minibatch loss", "value": 54.510612}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 17.214996}
# {"metric": "Training accuracy", "value": 0.99219}
# {"metric": "Minibatch loss", "value": 70.142883}
# {"metric": "Training accuracy", "value": 0.99219}
# {"metric": "Minibatch loss", "value": 152.893066}
# {"metric": "Training accuracy", "value": 0.98438}
# {"metric": "Minibatch loss", "value": 121.996819}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 86.053932}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 87.382935}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 302.879456}
# {"metric": "Training accuracy", "value": 0.96094}
# {"metric": "Minibatch loss", "value": 196.001877}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 235.883408}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 67.857117}
# {"metric": "Training accuracy", "value": 0.97656}
# {"metric": "Minibatch loss", "value": 273.333832}
# {"metric": "Training accuracy", "value": 0.96094}
# {"metric": "Minibatch loss", "value": 137.479309}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 442.456177}
# {"metric": "Training accuracy", "value": 0.95312}
# {"metric": "Minibatch loss", "value": 57.409439}
# {"metric": "Training accuracy", "value": 0.96875}
# {"metric": "Minibatch loss", "value": 188.089813}
# {"metric": "Training accuracy", "value": 0.96875}
# Optimization Finished!
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'./model/saved_model.pb'
# b'./model/saved_model.pb'

# %%
with tf.Session() as sess:
    sess.run(init)
    
    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", sess.run(accuracy, feed_dict={x: mnist.test.images[:256], y: mnist.test.labels[:256], keep_prob: 1.}))
# Out:
# Testing Accuracy: 0.1015625
